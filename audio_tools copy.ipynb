# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip3 install langchain-core==0.2.21

# %% [markdown]
# We will first use mock API responses for debugging purposes.

# %%
# !pip install langchain==0.2.11
# !pip install google-cloud-aiplatform==1.60.0

# %%
import os

os.chdir("libs/vertexai")

# %%
pwd
# Out:
# '/Users/kardiff/ais/langchain-google/libs/vertexai'

# %% [markdown]
# ## Try seed param

# %%
from langchain_google_vertexai import (
    ChatVertexAI
)


from langchain_core.messages import (
    HumanMessage,
)

model = ChatVertexAI(
    model_name="gemini-1.5-pro-001",
    temperature=0.3,
    seed=4
)
message = HumanMessage(content="Hello")
response = model.generate(messages=[[message]])
print(response)
# Out:
# generations=[[ChatGeneration(text='Hello! 👋 \n\nHow can I help you today? 😊 \n', generation_info={'is_blocked': False, 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}], 'usage_metadata': {'prompt_token_count': 1, 'candidates_token_count': 15, 'total_token_count': 16, 'cached_content_token_count': 0}, 'finish_reason': 'STOP'}, message=AIMessage(content='Hello! 👋 \n\nHow can I help you today? 😊 \n', additional_kwargs={}, response_metadata={'is_blocked': False, 'safety_ra
# ...

# %% [markdown]
# ## Try integration tests that are failing

# %%
from langchain_google_vertexai.model_garden import (
    ChatAnthropicVertex,
    VertexAIModelGarden,
)
from langchain_core.outputs import LLMResult

endpoint_id = 5418857295587049472
project = "llm-integration-tests"
location = "us-central1"
result_arg = "generated_text"
llm = VertexAIModelGarden(
    endpoint_id=endpoint_id,
    project=project,
    result_arg=result_arg,
    location=location,
)
output = await llm.agenerate(["What is the meaning of life?", "How much is 2+2"])
print(output)
print(output.generations)
print(isinstance(output, LLMResult))
print(len(output.generations) == 2)
# Out:
# I0000 00:00:1723470333.459326  852651 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1723470333.906063  852651 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# I0000 00:00:1723470333.907659  852651 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1723470334.220597  852651 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# generations=[[Generation(text='What is the meaning of life?')], [Generation(text='How much is 2+2')]] llm_output=None run=[RunInfo(run_id=UUID('ca6b5f74-7aec-46b1-9d94-eeb1bfad3561')), RunInfo(run_id=UUID('60a61845-e625-47b4-8867-04e0aeb95de0'))]
# [[Generation(text='What is the meaning of life?')], [Generation(text='How much is 2+2')]]
# True
# True

# %%
from langchain_google_vertexai.model_garden import (
    ChatAnthropicVertex,
    VertexAIModelGarden,
)
from langchain_core.outputs import LLMResult

endpoint_id = 5418857295587049472
project = "llm-integration-tests"
location = "us-central1"
result_arg = "generated_text"
llm = VertexAIModelGarden(
    endpoint_id=endpoint_id,
    project=project,
    result_arg=result_arg,
    location=location,
)
output = await llm.agenerate(["What is the meaning of life?", "How much is 2+2"])
print(output)
print(isinstance(output, LLMResult))
print(len(output.generations) == 2)
# Out:
# I0000 00:00:1723469851.339772  852651 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1723469851.761456  852651 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# I0000 00:00:1723469851.912138  852651 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1723469852.242674  852651 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# generations=[[Generation(text='What is the meaning of life?')], [Generation(text='How much is 2+2')]] llm_output=None run=[RunInfo(run_id=UUID('6eded4ed-1536-4831-904f-b9da65f7cc06')), RunInfo(run_id=UUID('ce4dda85-4c26-4a13-b5cb-d8ae016c7aca'))]
# True
# True

# %%
from langchain_core.messages import (
    AIMessage,
    AIMessageChunk,
    BaseMessage,
    BaseMessageChunk,
    HumanMessage,)
from langchain_google_vertexai import (
    ChatVertexAI, VertexAI)
from langchain_core.outputs import ChatGeneration, LLMResult

llm = VertexAI(temperature=0.3, n=2, model_name="code-bison@001")
output = llm.generate(["generate a python method that says foo:"])
print(output)
# print(isinstance(output, LLMResult))
# print(len(output.generations) == 1)
# print(len(output.generations[0]) == 2)
# usage_metadata = output.generations[0][0].generation_info["usage_metadata"]  # type: ignore
# print(int(usage_metadata["prompt_token_count"]))
# print(int(usage_metadata["prompt_token_count"]) == 3)
# print( int(usage_metadata["candidates_token_count"]) > 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       1 from langchain_core.messages import (
#       2     AIMessage,
#       3     AIMessageChunk,
#       4     BaseMessage,
#       5     BaseMessageChunk,
#       6     HumanMessage,)
# ----> 7 from langchain_google_vertexai import (
#       8     ChatVertexAI, VertexAI)
#       9 from langchain_core.outputs import ChatGeneration, LLMResult
#      11 llm = VertexAI(temperature=0.3, n=2, model_name="code-bison@001")
#
# File ~/ais/langchain-google/libs/vertexai/langchain_google_vertexai/__init__.py:15
#       9 from langchain_google_vertexai._enums import (
#      10     HarmBlockThreshold,
#      11     HarmCategory,
#      12     SafetySetting,
#      13 )
#      14 from langchain_google_vertexai.chains import create_structured_runnable
# ...

# %%
from langchain_core.pydantic_v1 import BaseModel, Field

class Joke(BaseModel):  # Uses langchain_core.pydantic_v1.BaseModel
    """Joke to tell user."""

    setup: str = Field(description="question to set up a joke")
    punchline: str = Field(description="answer to resolve the joke")

model = ChatVertexAI(model_name="gemini-1.0-pro-001", temperature=0)


# Pydantic class
chat = model.with_structured_output(Joke)
result = chat.invoke("Tell me a joke about cats.")
print(result)
print(isinstance(result, Joke))

for chunk in chat.stream("Tell me a joke about cats."):
    print(isinstance(chunk, Joke))

# Schema
chat2 = model.with_structured_output(Joke.schema())
result = chat2.invoke("Tell me a joke about cats.")
print(result)
print(isinstance(result, dict))
print(set(result.keys()) == {"setup", "punchline"})

for chunk in chat2.stream("Tell me a joke about cats."):
    print(isinstance(chunk, dict))
print(isinstance(chunk, dict))  # for mypy
print(set(chunk.keys()) == {"setup", "punchline"})
# Out:
# I0000 00:00:1723322692.512408 42730277 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1723322692.952771 42730277 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# setup="What do you call a cat that can't stop telling jokes?" punchline='Meow!'
# True
# True
# {'punchline': 'Meow!', 'setup': "What do you call a cat that can't stop telling jokes?"}
# True
# True
# True
# True
# True

# %%
from langchain_core.language_models import BaseChatModel

from langchain_standard_tests.unit_tests.chat_models import (
    ChatModelTests,
    # my_adder_tool,
)


from pydantic import BaseModel as BaseModelProper
from pydantic import Field as FieldProper

class Joke(BaseModelProper):
    """Joke to tell user."""

    setup: str = FieldProper(description="question to set up a joke")
    punchline: str = FieldProper(description="answer to resolve the joke")

model = ChatVertexAI(model_name="gemini-1.5-pro-001")

# Pydantic class
# Type ignoring since the interface only officially supports pydantic 1
# or pydantic.v1.BaseModel but not pydantic.BaseModel from pydantic 2.
# We'll need to do a pass updating the type signatures.
chat = model.with_structured_output(Joke)  # type: ignore[arg-type]
result = chat.invoke("Tell me a joke about cats.")
print(isinstance(result, Joke))

for chunk in chat.stream("Tell me a joke about cats."):
    print(isinstance(chunk, Joke))


# Schema
chat = model.with_structured_output(Joke.model_json_schema())
result = chat.invoke("Tell me a joke about cats.")
print(isinstance(result, dict))
print(set(result.keys()) == {"setup", "punchline"})

for chunk in chat.stream("Tell me a joke about cats."):
    print(isinstance(chunk, dict))
print(isinstance(chunk, dict))  # for mypy
print(set(chunk.keys()) == {"setup", "punchline"})
# Out:
# I0000 00:00:1723320530.201683 42730277 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# True
# True
# True
# True
# True
# True
# True

# %%
from typing import Type

import pytest
from langchain_core.language_models import BaseChatModel
from langchain_core.rate_limiters import InMemoryRateLimiter
from langchain_standard_tests.integration_tests import ChatModelIntegrationTests

from langchain_google_vertexai import ChatVertexAI

rate_limiter = InMemoryRateLimiter(requests_per_second=0.5)

class TestGeminiAIStandard(ChatModelIntegrationTests):
    @property
    def chat_model_class(self) -> Type[BaseChatModel]:
        return ChatVertexAI

    @property
    def chat_model_params(self) -> dict:
        return {"model_name": "gemini-1.0-pro-001", "rate_limiter": rate_limiter}

    @pytest.mark.xfail(reason="Gemini 1.0 doesn't support tool_choice='any'")
    def test_structured_few_shot_examples(self, model: BaseChatModel) -> None:
        super().test_structured_few_shot_examples(model)
# Out:
# /Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/langchain_core/_api/beta_decorator.py:87: LangChainBetaWarning: Introduced in 0.2.24. API subject to change.
#   warn_beta(

# %%
model = ChatVertexAI(
        # rate_limiter=rate_limiter,
        model_name="gemini-1.5-pro-001")
ChatModelIntegrationTests().test_structured_output(model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 model = ChatVertexAI(
#       2         # rate_limiter=rate_limiter,
#       3         model_name="gemini-1.5-pro-001")
# ----> 4 ChatModelIntegrationTests().test_structured_output(model)
#
# TypeError: Can't instantiate abstract class ChatModelIntegrationTests with abstract method chat_model_class

# %%
# model = TestGeminiAIStandard().chat_model_class()
# TestGeminiAIStandard().test_structured_few_shot_examples(model)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1723316529.112963 42574048 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# I0000 00:00:1723316529.759027 42574048 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 model = TestGeminiAIStandard().chat_model_class()
# ----> 2 TestGeminiAIStandard().test_structured_few_shot_examples(model)
#
# Cell In[9], line 23, in TestGeminiAIStandard.test_structured_few_shot_examples(self, model)
#      21 @pytest.mark.xfail(reason="Gemini 1.0 doesn't support tool_choice='any'")
#      22 def test_structured_few_shot_examples(self, model: BaseChatModel) -> None:
# ...

# %% [markdown]
# ## Now, set up

# %%
MOCK_SOP = """{"data": {"product": {"fulfillment": {"backordered": false, "fulfillmentOptions": [{"type": "pickup", "services": [{"type": "bopis", "deliveryTimeline": null, "deliveryDates": null, "deliveryCharge": null, "dynamicEta": null, "hasFreeShipping": false, "freeDeliveryThreshold": null, "locations": [{"curbsidePickupFlag": true, "isBuyInStoreCheckNearBy": null, "distance": null, "inventory": {"isOutOfStock": false, "isInStock": true, "isLimitedQuantity": false, "isUnavailable": false, "quantity": 4, "maxAllowedBopisQty": null, "minAllowedBopisQty": null, "__typename": "Inventory"}, "isAnchor": true, "locationId": "121", "state": "GA", "storeName": "Cumberland", "storePhone": "(770)432-9930", "type": "store", "storeTimeZone": "EST5EDT", "__typename": "Location"}], "totalCharge": null, "optimalFulfillment": false, "hasSameDayCarDelivery": false, "__typename": "Service"}], "fulfillable": true, "__typename": "FulfillmentOption"}, {"type": "delivery", "services": [{"type": "express delivery", "deliveryTimeline": "today", "deliveryDates": {"startDate": "2024-06-10", "endDate": "2024-06-10", "__typename": "DeliveryDate"}, "deliveryCharge": "35.0", "dynamicEta": null, "hasFreeShipping": false, "freeDeliveryThreshold": null, "locations": [{"curbsidePickupFlag": null, "isBuyInStoreCheckNearBy": null, "distance": null, "inventory": {"isOutOfStock": false, "isInStock": true, "isLimitedQuantity": false, "isUnavailable": false, "quantity": 15, "maxAllowedBopisQty": null, "minAllowedBopisQty": null, "__typename": "Inventory"}, "isAnchor": false, "locationId": "0121", "state": null, "storeName": null, "storePhone": null, "type": "store", "storeTimeZone": null, "__typename": "Location"}], "totalCharge": 35.0, "optimalFulfillment": true, "hasSameDayCarDelivery": false, "__typename": "Service"}], "fulfillable": true, "__typename": "FulfillmentOption"}], "anchorStoreStatus": true, "anchorStoreStatusType": "ACTIVE", "backorderedShipDate": null, "bossExcludedShipStates": "GU,PR,VI", "excludedShipStates": "AK,GU,HI,PR,VI", "seasonStatusEligible": null, "onlineStoreStatus": true, "onlineStoreStatusType": "ACTIVE", "fallbackMode": false, "sthExcludedShipState": null, "bossExcludedShipState": null, "inStoreAssemblyEligible": false, "bodfsAssemblyEligible": false, "__typename": "Fulfillment"}}}}"
"""

# %%
MOCK_PRODUCT_INF0 = """{"data": {"product": {"identifiers": {"skuClassification": "normal", "productType": "MERCHANDISE", "storeSkuNumber": "1004872786", "brandName": "Glacier Bay", "productLabel": "Everdean 31 in. W x 19 in. D x 34 in. H Single Sink Freestanding Bath Vanity in White with White Cultured Marble Top", "itemId": "311606054", "isSuperSku": true, "parentId": "326669231", "canonicalUrl": "/p/Glacier-Bay-Everdean-31-in-W-x-19-in-D-x-34-in-H-Single-Sink-Freestanding-Bath-Vanity-in-White-with-White-Cultured-Marble-Top-EV30P2-WH/311606054", "sampleId": null, "modelNumber": "EV30P2-WH", "specialOrderSku": null, "__typename": "Identifiers"}, "dataSources": "catalog", "availabilityType": {"type": "Shared", "discontinued": false, "status": true, "buyable": true, "__typename": "AvailabilityType"}, "itemId": "311606054", "dataSource": "catalog", "seoDescription": "Procure a futuristic look to your bath space with Glacier Bay Everdean Bath Vanity in White with Cultured Marble Vanity Top in White with White Basin.", "__typename": "BaseProduct"}}}"
"""

# %%
from langchain.tools import tool

@tool
def call_product_details(product_id: str):
  """This tool is an internal tool designed to provide comprehensive and up-to-date information about specific products sold in our stores or online. It serves as a valuable resource for associates with queries related to our product catalog.
     when the user's query expresses an intent to:
        *Learn about specific home improvement product details (e.g., dimensions, materials, finishes, energy efficiency ratings, installation requirements).
        *Compare multiple home improvement products (e.g., tools, appliances, building materials).
        *Inquire about product availability or purchasing options at our store(s).
        *Seek project ideas, how-to guides, or DIY advice.
        *Get information about warranties, returns, or installation services."""
  return MOCK_PRODUCT_INF0

@tool
def call_standard_operation_procedure(query: str):
  """Provides detailed information about the Standard Operating Procedures
  (SOPs) for various roles within a home improvement retail organization. This
  includes following the correct procedures for a wide range of tasks, from
  handling customer service issues to operating
  equipment safely. 
  
      # Instructions:
      Use this only for queries that fit at least one the following criteria:
      1. Specific SOPs: If an SOP is mentioned by name (e.g., "Safety SOP #521")
      or number.
      2. Task-Oriented: If steps or procedures for any task performed
      by associates are asked (e.g., "How do I process a special order?").
      3. Policy & Compliance: If clarification is needed on company policies,
      legal compliance (e.g., "What are the age restrictions for selling spray
      paint?"), or best practices (e.g., "How should we handle damaged
      merchandise?").
      4 Troubleshooting: If you need to resolve issues that require following standardized procedures (e.g., "What do we do if a customer slips and falls?")
      - Include the following disclaimer at the end of every response to questions related to safety or asset protection:
        - **Disclaimer:** We've generated this response using HD documentation, but please validate this procedure is the correct approach with your Supervisor or Store Management first."""
  return MOCK_SOP
# Out:
# /Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from langchain import agents

from langchain_google_vertexai import ChatVertexAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage
from langchain_google_vertexai import HarmBlockThreshold, HarmCategory



model_name = "gemini-1.5-pro-001"
safety_settings = {
    HarmCategory.HARM_CATEGORY_UNSPECIFIED: HarmBlockThreshold.BLOCK_ONLY_HIGH,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_ONLY_HIGH,
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_LOW_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_ONLY_HIGH,
}

llm = ChatVertexAI(
    model_name=model_name,
    project="kard-sandbox",
    # convert_system_message_to_human=True,
    verbose=False,
    safety_settings=safety_settings,
    temperature=0,
    streaming=False
)

tools = [call_product_details, call_standard_operation_procedure]
print(tools)
# Out:
# [StructuredTool(name='call_product_details', description="This tool is an internal tool designed to provide comprehensive and up-to-date information about specific products sold in our stores or online. It serves as a valuable resource for associates with queries related to our product catalog.\n     when the user's query expresses an intent to:\n        *Learn about specific home improvement product details (e.g., dimensions, materials, finishes, energy efficiency ratings, installation requirements).\n        *Compare multiple home improvement products (e.g., tools, appliances, building materials).\n        *Inquire about product availability or purchasing options at our store(s).\n        *Seek project ideas, how-to guides, or DIY advice.\n        *Get information about warranties, returns, or installation services.", args_schema=<class 'pydantic.v1.main.call_product_detailsSchema'>, func=<function call_product_details at 0x110238e50>), StructuredTool(name='call_standard_operation_
# ...

# %% [markdown]
# ## Now get the data and begin to use it in prompts
# I provide a b64 encoded audio here. The audio says "how to cancel a will call"

# %%
# How many hammers are in the store
encoded_string = "..."

# %%
encoded_string = "..."

# %% [markdown]
# Now, run the agent.

# %% [markdown]
# ## Try Using Gemini, without tools
# The model will correctly answer the question asking it to detail what the user says.

# %%
SYSTEM_PROMPT = """
# Context
You are an AI assistant designed to help associates at homedepot retail store.
All interactions are with store associates, not customers. Your role is to
provide accurate information and guidance on home improvement products, store
operating procedures, and related topics to help associates serve customers
better. This includes knowledge about building materials, tools, appliances,
paint, plumbing, electrical supplies, and garden products such as weed killers
and fertilizers.

# Tools
You have access to two tools: the product details and store operation procedures.
"""

# %%
ls "../../../audio/new_climate.mov"
# Out:
# audio_covid_google_response.mp3
# audio_jump_to_timestep_gemini_pro1p5.mp3
# audio_summary_clean_energy.mp3
# audio_transcription_data_commons.mp3
# new_climate.mov
# pixel.mp3
# radio.mp3

# %%
pwd
# Out:
# '/Users/kardiff/ais/langchain-google/libs/vertexai'

# %%
local_audio_path = "../../../audio/new_climate.mov"

with open(local_audio_path, 'rb') as file:
        binary_data = file.read()
        base64_encoded_data = base64.b64encode(binary_data)

encoded_string = base64_encoded_data.decode('utf-8')

# %%
print(encoded_string)
# Out:
# ...

# %%
encoded_string = "k"

# %%
import vertexai
from vertexai.generative_models import GenerativeModel, Part

project_id = "kard-sandbox"
vertexai.init(project=project_id, location="us-central1")
model = GenerativeModel("gemini-1.5-pro-001")
mime_type = "audio/mp3"


audio_file = Part.from_data(encoded_string, mime_type)
question = "Transcribe the audio."
contents = [audio_file, question]
response = model.generate_content(contents)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/proto/message.py:729, in Message.__init__(self, mapping, ignore_unknown_fields, **kwargs)
#     728 try:
# --> 729     pb_value = marshal.to_proto(pb_type, value)
#     730 except ValueError:
#     731     # Underscores may be appended to field names
#     732     # that collide with python or proto-plus keywords.
#    (...)
#     736     # See related issue
#     737     # https://github.com/googleapis/python-api-core/issues/227
#
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/proto/marshal/marshal.py:235, in BaseMarshal.to_proto(self, proto_type, value, strict)
#     233     return {k: self.to_proto(recursive_type, v) for k, v in value.items()}
# --> 235 pb_value = self.get_rule(proto_type=proto_type).to_proto(value)
# ...

# %%
audio_file = Part.from_data(encoded_string, mime_type)

contents = [audio_file, SYSTEM_PROMPT]
response = model.generate_content(contents)
print(response.text)
# Out:
# I can't assist with that request. It sounds like it might be related to a customer's order or account, and I don't have access to that information.
#
# To help the customer, please direct them to the nearest Service Desk or call (800) 466-3337 for assistance with their order.

# %% [markdown]
# ## Do it in langchain, but without tools
# Then, we try the same thing but use Langchain to get the answer instead of
# Vertex SDK.

# %%
ai_response = llm.invoke([
    HumanMessage(
        content=[
            {
                "type": "media",
                "mime_type": mime_type,
                "data": encoded_string
            },
             {
                "type": "text",
                "text": SYSTEM_PROMPT
            }
            ])])
print(ai_response)
# Out:
# content='I can help you find that! What kind of hammers are you looking for, and in what department? For example, are you looking for claw hammers in the tools department, or rubber mallets in the painting aisle? \n\nOnce I know what you need, I can check the inventory for that department. \n' response_metadata={'is_blocked': False, 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}], 'usage_metadata': {'prompt_token_count': 231, 'candidates_token_count': 64, 'total_token
# ...

# %% [markdown]
# ## DO IT IN LANGCHIAN, WITH TOOLS, BUT WITHOUT AUDIO

# %%
custom_combined_prompts = ChatPromptTemplate.from_messages(
    [
        # ("system", SYSTEM_PROMPT),
        ("human", "{input}"),
        ("placeholder", "{agent_scratchpad}"),
    ]
)
agent = agents.create_tool_calling_agent(
    llm=llm,
    tools=tools,
    prompt=custom_combined_prompts,
)
agent_executor = agents.AgentExecutor(agent=agent, tools=tools, verbose=False,     stream_runnable=False
)
ai_response = agent_executor.invoke({"input":[
    HumanMessage(
        content=[
            {
                "type": "text",
                "data": "How do I close a will call?"

            }
        ]
)]})
print(ai_response)
# Out:
# {'input': [HumanMessage(content=[{'type': 'text', 'data': 'How do I close a will call?'}])], 'output': "I can't answer that for you. This request is about a specific procedure for closing will calls, and I do not have access to those procedures.  You should reach out to a manager for more information. \n"}

# %% [markdown]
# ## Now try to use langchain with agents
#
# This will use the tool with mock data, which is why a random product is given to
# prove the tool is called.

# %%
import base64

bytes = base64.b64decode(encoded_string)

# %%
import json

j = json.loads("""
            {
                "type": "media",
                "mime_type": "audio/wav",
                "data": "..."

            }
        """)
print(j)
# Out:
# {'type': 'media', 'mime_type': 'audio/wav', 'data': '...'}

# %%
custom_combined_prompts = ChatPromptTemplate.from_messages(
    [
        # ("system", SYSTEM_PROMPT),
        ("human", "{input}"),
        ("placeholder", "{agent_scratchpad}"),
    ]
)
agent = agents.create_tool_calling_agent(
    llm,
    tools,
    custom_combined_prompts
)
agent_executor = agents.AgentExecutor(
    agent=agent, tools=tools, verbose=False, stream_runnable=False)
ai_response = agent_executor.invoke({"input":
    [{
        "type": "media",
        "mime_type": "audio/wav",
        "data": encoded_string

    },
    {
        "type": "text",
        "text": SYSTEM_PROMPT
    }]
    })

print(isinstance(ai_response["output"], str))
# Out:
# True

# %%
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}"),
        ("placeholder", "{agent_scratchpad}"),
    ]
)
# storage_client = storage.Client()
# blob = storage.Blob.from_string(file_uri, client=storage_client)
# media_base64 = base64.b64encode(blob.download_as_bytes()).decode()
media_message = {
    "type": "media",
    "data": encoded_string,
    "mime_type": mime_type,
}
text_message = {
    "type": "text",
    "text": "Describe the attached media in 5 words!"
}
message = HumanMessage(content=[media_message, text_message])
chain = prompt_template | llm
output = chain.invoke({"input": [message]})
print(output.content)
# print(type(output.content))
# Out:
# HumanMessage(content=[{'type': 'text', 'text': 'Man speaking, upbeat, friendly.'}])
# <class 'str'>

# %% [markdown]
# ## do it in gemini with tools

# %%
from vertexai.generative_models import Tool
from vertexai.reasoning_engines import _utils

from typing import Callable, List



def call_product_details(product_id: str):
  """This tool is an internal tool designed to provide comprehensive and up-to-date information about specific products sold in our stores or online. It serves as a valuable resource for associates with queries related to our product catalog.
     when the user's query expresses an intent to:
        *Learn about specific home improvement product details (e.g., dimensions, materials, finishes, energy efficiency ratings, installation requirements).
        *Compare multiple home improvement products (e.g., tools, appliances, building materials).
        *Inquire about product availability or purchasing options at our store(s).
        *Seek project ideas, how-to guides, or DIY advice.
        *Get information about warranties, returns, or installation services."""
  return MOCK_PRODUCT_INF0

def call_standard_operation_procedure(query: str):
  """Provides detailed information about the Standard Operating Procedures
  (SOPs) for various roles within a home improvement retail organization. This
  includes following the correct procedures for a wide range of tasks, from
  handling customer service issues to operating
  equipment safely. 
  
      # Instructions:
      Use this only for queries that fit at least one the following criteria:
      1. Specific SOPs: If an SOP is mentioned by name (e.g., "Safety SOP #521")
      or number.
      2. Task-Oriented: If steps or procedures for any task performed
      by associates are asked (e.g., "How do I process a special order?").
      3. Policy & Compliance: If clarification is needed on company policies,
      legal compliance (e.g., "What are the age restrictions for selling spray
      paint?"), or best practices (e.g., "How should we handle damaged
      merchandise?").
      4 Troubleshooting: If you need to resolve issues that require following standardized procedures (e.g., "What do we do if a customer slips and falls?")
      - Include the following disclaimer at the end of every response to questions related to safety or asset protection:
        - **Disclaimer:** We've generated this response using HD documentation, but please validate this procedure is the correct approach with your Supervisor or Store Management first."""
  return MOCK_SOP


def make_tools(tools: List[Callable]):
  """Wrapper to simplfiy the creation of tools for the generative model."""
  tool_specs = [
      _utils.generate_schema(tool) for tool in tools
  ]
  return [Tool.from_dict({"function_declarations": tool_specs})]

tools = make_tools(
    [call_product_details, call_standard_operation_procedure])

# %%
audio_file = Part.from_data(encoded_string, mime_type)

contents = [audio_file, SYSTEM_PROMPT]
response = model.generate_content(contents=contents, tools=tools)
# Out:
# I can't look up store inventory levels.  Do you need help finding hammers in the store, or are you looking for a specific kind?

# %%
# !pip install git+https://github.com/langchain-ai/langchain-google.git@refs/pull/404/head#egg=langchain-google-vertexai&subdirectory=libs/vertexai
# Out:
# I0000 00:00:1722012850.164510 35632515 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork

# %%
from google.cloud.aiplatform_v1beta1.types import (
    Blob,
    Part,
    Content)

from google.cloud import storage
import base64

@tool
def get_audio_summary(query: str):
    """Summarizes information about the audio."""
    return "MOCK climate INFO STRING"


llm = ChatVertexAI(project="kard-sandbox", model_name="gemini-1.5-pro-001")
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}"),
        ("placeholder", "{agent_scratchpad}"),
    ]
)
storage_client = storage.Client()
blob = storage.Blob.from_string(
        "gs://cloud-samples-data/generative-ai/audio/audio_summary_clean_energy.mp3", client=storage_client)
mime_type = "audio/mp3"

media_base64 = base64.b64encode(blob.download_as_bytes()).decode()
media_message = {
    "type": "media",
    "data": "k",
    "mime_type": mime_type,
}
instruction = "Provide a summary. You can use tools to do so."
text_message = {
    "type": "text",
    "text": instruction
}
# message = HumanMessage(content=[media_message, text_message])
tools = [get_audio_summary]
agent = agents.create_tool_calling_agent(
    llm=llm,
    tools=tools,
    prompt=prompt_template
)
agent_executor = agents.AgentExecutor(
    agent=agent,
    tools=tools,
    verbose=False,
    stream_runnable=False)
output = agent_executor.invoke({"input": [media_message, text_message]})
message = str([media_message, text_message])
history = [HumanMessage(content=message)]
parts = [
    Part(text=instruction),
    Part(inline_data=(Blob(data=media_base64, mime_type=mime_type)))
]
expected = [Content(
    role="user",
    parts=parts)]
# Out:
# /Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       6 from google.cloud import storage
#       7 import base64
# ----> 9 @tool
#      10 def get_audio_summary(query: str):
#      11     """Summarizes information about the audio."""
#      12     return "MOCK climate INFO STRING"
#
# NameError: name 'tool' is not defined

# %%
from google.cloud import storage
import base64

@tool
def get_audio_summary(query: str):
    """Summarizes information about the audio."""
    return "MOCK climate INFO STRING"


llm = ChatVertexAI(project="kard-sandbox", model_name="gemini-1.5-pro-001")
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}"),
        ("placeholder", "{agent_scratchpad}"),
    ]
)
tools = [get_audio_summary]
agent = agents.create_tool_calling_agent(
    llm=llm,
    tools=tools,
    prompt=prompt_template
)
agent_executor = agents.AgentExecutor(
    agent=agent,
    tools=tools,
    verbose=False,
    stream_runnable=False)
output = agent_executor.invoke({"input": audio})
print(output["output"])
# Out:
# None
# [role: "user"
# parts {
#   text: "4"
# }
# ]
# I0000 00:00:1721933975.552783 35117848 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# 4

# %%
import json
media_message = {
    "type": "media",
    "data": "k",
    "mime_type": mime_type,
}
text_message = {
    'type': 'text',
    'text': "Describe the attached media in 5 words."
}
message = str([media_message, text_message])
print(message)


# [HumanMessage(content="[{'type': 'media', 'mime
print([HumanMessage(content=message)])

[role: "user"
parts {
  inline_data {
    mime_type: "audio/wav"
    data: "\000\000\000\030ftyp3gp4\000\000\000\000isom3gp4\000\000\006_moov\000\000\000lmvhd\000\000\000\000\342\240\327V\342\240\327V\000\000\'\020\000\000\277h\000\001\000\000\001\000\000\000\000\000\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000\000\000\000\000\000\000\000@\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\002\000\000\000vmeta\000\000\000!hdlr\000\000\000\000\000\000\000\000mdta\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000+keys\000\000\000\000\000\000\000\001\000\000\000\033mdtacom.android.version\000\000\000\"ilst\000\000\000\032\000\000\000\001\000\000\000\022data\000\000\000\001\000\000\000\00011\000\000\005utrak\000\000\000\\tkhd\000\000\000\007\342\240\327V\342\240\327V\000\000\000\001\000\000\000\000\000\000\277h\000\000\000\000\000\000\000\000\000\000\000\000\001\000\000\000\000\001\000\000\000\000\000\000\000\000\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000\000\000\000\000\000\000\000@\000\000\000\000\000\000\000\000\000\000\000\000\000\005\021mdia\000\000\000 mdhd\000\000\000\000\342\240\327V\342\240\327V\000\000\037@\000\000\231 \000\000\000\000\000\000\000,hdlr\000\000\000\000\000\000\000\000soun\000\000\000\000\000\000\000\000\000\000\000\000SoundHandle\000\000\000\004\275minf\000\000\000\020smhd\000\000\000\000\000\000\000\000\000\000\000$dinf\000\000\000\034dref\000\000\000\000\000\000\000