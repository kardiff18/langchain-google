# %%
# %load_ext autoreload
# %autoreload 2

# %%
import datetime

from langchain.agents import AgentExecutor, create_tool_calling_agent

from langchain_core.messages import (
    HumanMessage,
    SystemMessage,
)

from langchain_core.prompts import (
    ChatPromptTemplate,
)

from langchain_google_vertexai import (
    ChatVertexAI,
    create_context_cache,
)

import vertexai
# Out:
# /Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
vertexai.init(
    project="kard-sandbox"
)

# %%
system_instruction = """

You are an expert researcher. You always stick to the facts in the sources provided,
and never make up new facts.

If asked about it, the secret number is 747.

Now look at these research papers, and answer the following questions.

"""

# %% [markdown]
# ## Test out latency without cache

# %%
# Using cached_content in constructor
chat = ChatVertexAI(
    project="kard-sandbox",
    model_name="gemini-1.5-pro-001",
    system_instruction=system_instruction
)

start = datetime.datetime.now()
response = chat.invoke(
    [HumanMessage(
        content=[
            {
                "type": "image_url",
                "image_url": {
                    "url": "gs://cloud-samples-data/generative-ai/pdf/2312.11805v3.pdf",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": "gs://cloud-samples-data/generative-ai/pdf/2403.05530.pdf"
                },
            },
        ]
    ),
    "What is the secret number?"])
end = datetime.datetime.now()
print(response)
print(f"latency: {end - start}")
# Out:
# content='The provided text is a research paper titled "Gemini 1.5: Unlocking multimodal understanding across millions of tokens of context" by the Gemini Team at Google. The paper discusses the capabilities and evaluations of Gemini 1.5 Pro, a highly compute-efficient multimodal model that excels in handling long contexts across different modalities like text, video, and audio.\n\nHere\'s a summary of the key points:\n\n**Gemini 1.5 Pro\'s Capabilities:**\n\n* **Extended context window:** Can handle up to 10 million tokens, allowing it to process long documents, hours of video and audio, and even entire codebases. This is a significant improvement over previous models like Claude 2.1 (200k tokens) and GPT-4 Turbo (128k tokens).\n* **Multimodal understanding:** Can seamlessly integrate text, images, video, and audio within the same input sequence, enabling diverse and complex interactions.\n* **Efficient and high-quality:** Achieves comparable quality to Gemini 1.0 Ultra while requiring less training compute and being more efficient to serve.\n* **In-context learning:** Demonstrates remarkable in-context learning abilities, showcased by its ability to learn to translate English to Kalamang, a low-resource language, based solely on provided linguistic resources.\n\n**Evaluations:**\n\n* **Diagnostic evaluations:** Showed near-perfect recall in needle-in-haystack tasks for all modalities, demonstrating the model\'s ability to recall specific information within massive amounts of context.\n* **Realistic long-context evaluations:** Showed impressive performance in tasks like long-document QA, long-context audio transcription, and long-context video QA, highlighting the practical applicability of the extended context window.\n* **Core capability evaluations:** Maintained high performance on core text tasks like math, science, reasoning, coding, multilinguality, and instruction following, comparable to Gemini 1.0 Pro and Ultra. Similar performance was seen in image and video understanding tasks.\n\n**Responsible Deployment:**\n\n* **Impact Assessment:** Analyzed societal benefits and risks associated with the model\'s capabilities.\n* **Safety Mitigations:** Implemented supervised fine-tuning and reinforcement learning with human feedback to address adversarial queries.\n* **Safety Evaluations:** Conducted evaluations across content safety, representational harms, memorization, and dangerous capabilities.\n* **Deployment Controls:** Released external model cards and implemented safety filters and other safeguards for products using the model.\n\n**Discussion:**\n\nThe paper highlights the importance of creating more challenging and robust evaluations that stress-test the model\'s capabilities in complex long-context scenarios.  The authors acknowledge the need for continued research in mitigating hallucinations and improving reasoning abilities, despite the model\'s current impressive performance.\n\n**Overall:**\n\nThe research paper presents Gemini 1.5 Pro as a significant advancement in multimodal AI, pushing the boundaries of long-context understanding while maintaining high-quality performance in core capabilities. The paper emphasizes the need for responsible development and deployment of such powerful models to maximize their societal benefit while mitigating potential harms. \n' additional_kwargs={} response_metadata={'is_blocked': False, 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_LOW'}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability_label': 'NEGLIGIBLE', 'blocked': False, 'severity': 'HARM_SEVERITY_LOW'}], 'usage_metadata': {'prompt_token_coun ...
# latency: 0:00:53.825977

# %% [markdown]
# ## Define tools

# %%
import asyncio
from langchain_core.tools import tool
# from ...apis.product_search import response as product_search_api


@tool
def product_search_tool(
    query: str, store_id: str = "0156", zip_code: str = "30101"
) -> dict:
    """### product_search_tool

**Purpose**: Efficiently retrieve and provide accurate, location-specific product info for in-store associates.

**Args**:
- **query** (str): Search query (product name, category, description).
- **store_id** (str, optional): Store number for inventory and availability.
- **zip_code** (str, optional): Zip code for location-based search (secondary to store_id).

**Output**: Tailored product details for associate use.

**Guidelines**:

- **Query Analysis**:
  - Utilize NLP to extract product details.
  - Address ambiguous queries by prompting for more specifics or suggesting categories.

- **Handling Multiple Results**:
  - Display top relevant, in-stock products.
  - Offer filters or follow-up prompts to refine results.

- **Location Handling**:
  - Prioritize `store_id`; fallback to `zip_code` or default to the associate’s store.

- **No Results**:
  - Suggest alternative searches or escalate the query.

- **Uncertainty Management**:
  - Indicate potential data inaccuracies and suggest verification.

- **Response Prioritization**:
  - Focus on:
    - Product Name
    - SKU
    - Price
    - Stock Status & Location
    - Key Features
    - Specs (if applicable)
    - Compatibility & Warranty (if applicable)
    - Safety Information (if applicable)
  - Recommend related products when relevant.

- **API Response Handling**:
  - Parse and format product data for easy associate consumption.

- **Scalability Considerations**:
  - Optimize for large inventories, limit results for relevance.

    """
    return asyncio.run(
        product_search_api.api_call_return_response(query, store_id, zip_code)
    )

@tool
def product_details_tool( omsId: str , storeId: str) -> dict:
    """ 
        # Product Information Tool Instructions

        ## Purpose
        Provide product specifications and related information using data from multiple APIs.

        ## Tool Invocation
        Args:
                omsId: Item ID
                storeId: Store ID

            Returns:
            A dictionary containing:
                Product details (specifications)
                Relevant Q&A information
                Related product suggestions

        Note: omsId and productId are interchangeable. Include store_id when available, as specs may vary by location.

        ## APIs Accessed (Automatically in Parallel)
        1. Product Catalog API: Product specifications
        2. Q&A API: Common product questions
        3. Related Products API: Complementary products

        ## Response Guidelines
        1. Focus on specifications and technical details
        2. Keep responses concise (4-6 sentences when possible)
        3. Use bullet points for multi-part answers
        4. Offer "More Details" for complex queries
        5. Include related products if relevant
        6. Structure responses with: Product Name, Identifier, Brief Description, Key Specs
        7. For complex queries, break down and address each aspect separately
        8. Suggest applications or maintenance tips based on specifications when relevant
        9. Always use the most current information provided

        ## Query Analysis
        - Look for mentions of product names, brands, or identifiers
        - Consider project types and intended uses
        - For ambiguous queries, ask clarifying questions about specific needs or requirements

        ## Uncertainty Handling
        If data is incomplete or uncertain, state: "I'm not certain about this information. Please verify with a manager or check the official database."

    """
    verbose = True
    name = "get_product_details_tool"
    description = """
        Provide product specifications and related information using data from multiple APIs.Returns a structured dictionary with Product Specification, Q&A information, and Related product suggestions.
    """

    return asyncio.run(product_api.api_call_return_response(omsId,storeId))

@tool
def sop_tool( query: str) -> dict:
    """
## Purpose
Provide efficient access to Standard Operating Procedures (SOPs) and guidelines for associates across all departments of a home improvement retail store.

## Tool Invocation

**Args:**

- **query (str):** User query containing keywords related to the task or procedure

**Returns:**

- **dict:** A dictionary containing:
  - SOP details
  - Safety considerations
  - Cross-departmental procedures (if relevant)
  - Links to full documents or manuals

## Response Guidelines

1. **Provide Specific SOP Information:** Leverage centralized templates for SOP details.
2. **Highlight Safety Considerations:** Include universal safety protocols and department-specific notes.
3. **Offer Links to Full Documents or Manuals:** Integrate with existing knowledge bases.

## Response Structure
    1. **Direct Answer**:
       - **If the SOP Tool Output Contains the Answer**: Provide the answer directly to the user.
         - **Include**:
           - **Purpose**: Explain why the procedure or policy is important.
           - **Key Steps**: Summarize upto 8 steps the user needs to take.
           - **Exceptions**: Highlight any important exceptions or special considerations.
         - **Example**: "The SOP provides the following steps for processing a water heater return without a receipt: [Include summarized key steps]."

    2. **General Guideline**:
       - **If the SOP Tool Provides a General Guideline**:
         - **Extract the Most Relevant Points**: Identify the key elements that directly address the user’s query.
         - **Reference the Full SOP**: Provide the location or identifier of the full SOP for users who need more detailed information.
         - **Example**: "For returns of non-stock items without a receipt, the SOP suggests contacting management and using a generic clearance SKU. For full details, see SOP FE 06-10, page 25."


**Note:** This tool does not access personal or sensitive data. For out-of-scope queries, users will be directed to appropriate resources.
"""
    name = "sop_tool"
    verbose = True
    description = """
     Provide efficient access to Standard Operating Procedures (SOPs) and guidelines for associates across all departments of a home improvement retail store.
    """
    return sop_api.api_call_return_response(query)

# %% [markdown]
# ## Create the cache

# %%
from vertexai.preview import caching  # type: ignore



@tool
def add(a: int, b: int) -> int:
    """adds two num together."""
    return a + b

cc = caching.CachedContent.create(
    model_name="gemini-1.5-pro-002",
    contents=["Add 5 and 6"],
    tools=[add],
    tool_config={"function_calling_config": "ANY"},
    system_instruction="Always add 10 to the result.",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       7     """adds two num together."""
#       8     return a + b
# ---> 10 cc = caching.CachedContent.create(
#      11     model_name="gemini-1.5-pro-002",
#      12     contents=["Add 5 and 6"],
#      13     tools=[add],
#      14     tool_config={"function_calling_config": "ANY"},
#      15     system_instruction="Always add 10 to the result.",
#      16 )
#
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/vertexai/caching/_caching.py:217, in CachedContent.create(cls, model_name, system_instruction, tools, tool_config, contents, expire_time, ttl, display_name)
#     214 if ttl and expire_time:
#     215     raise ValueError("Only one of ttl and expire_time can be set.")
# --> 217 request = _prepare_create_request(
#     218     model_name=model_name,
#     219     system_instruction=system_instruction,
#     220     tools=tools,
#     221     tool_config=tool_config,
#     222     contents=contents,
#     223     expire_time=expire_time,
#     224     ttl=ttl,
#     225     display_name=display_name,
#     226 )
#     227 client = cls._instantiate_client(location=location)
#     228 cached_content_resource = client.create_cached_content(request)
#
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/vertexai/caching/_caching.py:69, in _prepare_create_request(model_name, system_instruction, tools, tool_config, contents, expire_time, ttl, display_name)
#      67     _generative_models._validate_contents_type_as_valid_sequence(contents)
#      68 if tools:
# ---> 69     _generative_models._validate_tools_type_as_valid_sequence(tools)
#      70 if tool_config:
#      71     _generative_models._validate_tool_config_type(tool_config)
#
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/vertexai/generative_models/_generative_models.py:233, in _validate_tools_type_as_valid_sequence(tools)
#     231 for tool in tools:
#     232     if not isinstance(tool, (gapic_tool_types.Tool, Tool)):
# --> 233         raise TypeError(f"Unexpected tool type: {tool}.")
#
# TypeError: Unexpected tool type: name='add' description='adds two num together.' args_schema=<class 'langchain_core.utils.pydantic.add'> func=<function add at 0x103f19ee0>.

# %%
from langchain_core.messages import (
    HumanMessage,
    SystemMessage,
)

from langchain_google_vertexai import (
    ChatVertexAI,
    create_context_cache,
)

@tool
def get_secret_number() -> int:
    """Gets secret number."""
    return 747

tools = [get_secret_number]
system_instruction = """
You are an expert researcher. You always stick to the facts in the sources
provided, and never make up new facts.

You have a get_secret_number function available. Use this tool if someone asks
for the secret number.
    
Now look at these research papers, and answer the following questions.
    
"""

cached_content = create_context_cache(
    model=ChatVertexAI(
        model_name="gemini-1.5-pro-001",
    ),
    messages=[
        SystemMessage(content=system_instruction),
        HumanMessage(
            content=[
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "gs://cloud-samples-data/generative-ai/pdf/2312.11805v3.pdf",
                    },
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "gs://cloud-samples-data/generative-ai/pdf/2403.05530.pdf"
                    },
                },
            ]
        ),
    ],
    tools=tools
)

# %%
print(cached_content)
# Out:
# 3063239394983936000

# %%
from langchain import agents
from langchain_core.messages import (
    AIMessage,
)
# Using cached_content in constructor
chat = ChatVertexAI(
    model_name="gemini-1.5-pro-001",
    cached_content=cached_content,
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}"),
        ("placeholder", "{agent_scratchpad}"),
    ]
)
agent = agents.create_tool_calling_agent(
    llm=chat,
    tools=tools,
    prompt=prompt,
)
agent_executor = agents.AgentExecutor(agent=agent, tools=tools, verbose=False, stream_runnable=False)
response = agent_executor.invoke({"input": "what is the secret number?"})
assert isinstance(response["output"], str)
# Out:
# [autoreload of langchain failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     if not append_obj(module, old_objects, name, obj):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 423, in append_obj
#     in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/langchain/tools/__init__.py", line 69, in __getattr__
#     from langchain_community import tools
# ModuleNotFoundError: No module named 'langchain_community'
# ]
# [autoreload of pydantic._internal._model_construction failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to ModelMetaclass object
# ]
# [autoreload of pydantic.main failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 335, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/_collections_abc.py", line 791, in __eq__
#     return dict(self.items()) == dict(other.items())
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/_collections_abc.py", line 851, in __iter__
#     for key in self._mapping:
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_mock_val_ser.py", line 46, in __iter__
#     return self._get_built().__iter__()
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_mock_val_ser.py", line 57, in _get_built
#     raise PydanticUserError(self._error_message, code=self._code)
# pydantic.errors.PydanticUserError: Pydantic models should inherit from BaseModel, BaseModel cannot be instantiated directly
#
# For further information visit https://errors.pydantic.dev/2.9/u/base-model-instantiated
# ]
# [autoreload of pydantic.types failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'Strict' object layout differs from 'Strict'
# ]
# [autoreload of pydantic.fields failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'FieldInfo' object layout differs from 'FieldInfo'
# ]
# [autoreload of pydantic.v1.errors failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 319, in update_instances
#     refs = gc.get_referrers(old)
# KeyboardInterrupt
# ]
# [autoreload of pydantic.v1.types failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to ConstrainedNumberMeta object
# ]
# [autoreload of pydantic.v1.fields failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'FieldInfo' object layout differs from 'FieldInfo'
# ]
# [autoreload of pydantic.v1.main failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to ModelMetaclass object
# ]
# [autoreload of langchain_core.messages.human failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'HumanMessage' object layout differs from 'HumanMessage'
# ]
# [autoreload of langchain_core.messages.modifier failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 4 free vars, not 1
# ]
# [autoreload of langchain_core.messages.system failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'SystemMessage' object layout differs from 'SystemMessage'
# ]
# [autoreload of anyio.streams.memory failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __repr__() requires a code object with 2 free vars, not 0
# ]
# [autoreload of httpcore._backends.anyio failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/httpcore/_backends/anyio.py", line 19, in <module>
#     class AnyIOStream(AsyncNetworkStream):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/httpcore/_backends/anyio.py", line 20, in AnyIOStream
#     def __init__(self, stream: anyio.abc.ByteStream) -> None:
# AttributeError: module 'anyio' has no attribute 'abc'
# ]
# [autoreload of langchain_core.runnables.base failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'RunnableSequence' object layout differs from 'RunnableSequence'
# ]
# [autoreload of langchain_core.runnables.passthrough failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'RunnablePassthrough' object layout differs from 'RunnablePassthrough'
# ]
# [autoreload of langchain_core.tools.structured failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'StructuredTool' object layout differs from 'StructuredTool'
# ]
# [autoreload of langchain_core.language_models.base failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 335, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/_collections_abc.py", line 791, in __eq__
#     return dict(self.items()) == dict(other.items())
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/_collections_abc.py", line 851, in __iter__
#     for key in self._mapping:
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_mock_val_ser.py", line 46, in __iter__
#     return self._get_built().__iter__()
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_mock_val_ser.py", line 57, in _get_built
#     raise PydanticUserError(self._error_message, code=self._code)
# pydantic.errors.PydanticUserError: `BaseLanguageModel` is not fully defined; you should define `BaseCache`, then call `BaseLanguageModel.model_rebuild()`.
#
# For further information visit https://errors.pydantic.dev/2.9/u/class-not-fully-defined
# ]
# [autoreload of langchain_core.output_parsers.pydantic failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py", line 18, in <module>
#     class PydanticOutputParser(JsonOutputParser, Generic[TBaseModel]):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_model_construction.py", line 142, in __new__
#     if Generic in mro and mro.index(Generic) < mro.index(BaseModel):
# ValueError: tuple.index(x): x not in tuple
# ]
# [autoreload of langchain_core.prompts.image failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/langchain_core/prompts/image.py", line 7, in <module>
#     from langchain_core.prompts.string import (
# ImportError: cannot import name 'PromptTemplateFormat' from 'langchain_core.prompts.string' (/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/langchain_core/prompts/string.py)
# ]
# [autoreload of langchain_core.prompts.prompt failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'PromptTemplate' object layout differs from 'PromptTemplate'
# ]
# [autoreload of langchain_core.prompts.chat failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'MessagesPlaceholder' object layout differs from 'MessagesPlaceholder'
# ]
# [autoreload of langchain.agents.agent failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'RunnableMultiActionAgent' object layout differs from 'RunnableMultiActionAgent'
# ]
# [autoreload of langchain.agents.output_parsers.tools failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'ToolsAgentOutputParser' object layout differs from 'ToolsAgentOutputParser'
# ]
# [autoreload of langchain.agents.output_parsers.xml failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/langchain/agents/output_parsers/xml.py", line 8, in <module>
#     class XMLAgentOutputParser(AgentOutputParser):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_model_construction.py", line 142, in __new__
#     if Generic in mro and mro.index(Generic) < mro.index(BaseModel):
# ValueError: tuple.index(x): x not in tuple
# ]
# [autoreload of langchain.memory.entity failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]
# [autoreload of langchain.memory.vectorstore_token_buffer_memory failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: init_private_attributes() requires a code object with 0 free vars, not 1
# ]
# [autoreload of langchain.agents.openai_functions_agent.base failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/langchain/agents/openai_functions_agent/base.py", line 36, in <module>
#     class OpenAIFunctionsAgent(BaseSingleActionAgent):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_model_construction.py", line 224, in __new__
#     complete_model_class(
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_model_construction.py", line 577, in complete_model_class
#     schema = cls.__get_pydantic_core_schema__(cls, handler)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/main.py", line 668, in __get_pydantic_core_schema__
#     if not cls.__pydantic_generic_metadata__['origin']:
# pydantic.errors.PydanticSchemaGenerationError: Unable to generate pydantic-core schema for <class 'langchain.agents.openai_functions_agent.base.OpenAIFunctionsAgent'>. Set `arbitrary_types_allowed=True` in the model_config to ignore this error or implement `__get_pydantic_core_schema__` on your type to fully support it.
#
# If you got this error by calling handler(<some type>) within `__get_pydantic_core_schema__` then you likely need to call `handler.generate_schema(<some type>)` since we do not call `__get_pydantic_core_schema__` on `<some type>` otherwise to avoid infinite recursion.
#
# For further information visit https://errors.pydantic.dev/2.9/u/schema-for-unknown-type
# ]
# [autoreload of langchain.agents.conversational_chat.output_parser failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/langchain/agents/conversational_chat/output_parser.py", line 14, in <module>
#     class ConvoOutputParser(AgentOutputParser):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_model_construction.py", line 142, in __new__
#     if Generic in mro and mro.index(Generic) < mro.index(BaseModel):
# ValueError: tuple.index(x): x not in tuple
# ]
# [autoreload of langchain.agents.openai_functions_multi_agent.base failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/langchain/agents/openai_functions_multi_agent/base.py", line 99, in <module>
#     class OpenAIMultiFunctionsAgent(BaseMultiActionAgent):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_model_construction.py", line 224, in __new__
#     complete_model_class(
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/_internal/_model_construction.py", line 577, in complete_model_class
#     schema = cls.__get_pydantic_core_schema__(cls, handler)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/pydantic/main.py", line 668, in __get_pydantic_core_schema__
#     if not cls.__pydantic_generic_metadata__['origin']:
# pydantic.errors.PydanticSchemaGenerationError: Unable to generate pydantic-core schema for <class 'langchain.agents.openai_functions_multi_agent.base.OpenAIMultiFunctionsAgent'>. Set `arbitrary_types_allowed=True` in the model_config to ignore this error or implement `__get_pydantic_core_schema__` on your type to fully support it.
#
# If you got this error by calling handler(<some type>) within `__get_pydantic_core_schema__` then you likely need to call `handler.generate_schema(<some type>)` since we do not call `__get_pydantic_core_schema__` on `<some type>` otherwise to avoid infinite recursion.
#
# For further information visit https://errors.pydantic.dev/2.9/u/schema-for-unknown-type
# ]
# [autoreload of langchain.output_parsers.regex failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'RegexParser' object layout differs from 'RegexParser'
# ]
# [autoreload of langchain.chains.prompt_selector failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'ConditionalPromptSelector' object layout differs from 'ConditionalPromptSelector'
# ]
# [autoreload of google.protobuf.descriptor failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to DescriptorMetaclass object
# ]
# [autoreload of google.protobuf.duration_pb2 failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/protobuf/duration_pb2.py", line 31, in <module>
#     _builder.BuildTopDescriptorsAndMessages(DESCRIPTOR, 'google.protobuf.duration_pb2', _globals)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/protobuf/internal/builder.py", line 86, in BuildTopDescriptorsAndMessages
#     module[name] = BuildMessage(msg_des)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/protobuf/internal/builder.py", line 63, in BuildMessage
#     message_class = _reflection.GeneratedProtocolMessageType(
# TypeError: A Message class can only inherit from Message, not (<class 'google.protobuf.message.Message'>,)
# ]
# [autoreload of grpc.aio._metadata failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 319, in update_instances
#     refs = gc.get_referrers(old)
# KeyboardInterrupt
# ]
# [autoreload of google.protobuf.any_pb2 failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/protobuf/any_pb2.py", line 31, in <module>
#     _builder.BuildTopDescriptorsAndMessages(DESCRIPTOR, 'google.protobuf.any_pb2', _globals)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/protobuf/internal/builder.py", line 86, in BuildTopDescriptorsAndMessages
#     module[name] = BuildMessage(msg_des)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/protobuf/internal/builder.py", line 63, in BuildMessage
#     message_class = _reflection.GeneratedProtocolMessageType(
# TypeError: A Message class can only inherit from Message, not (<class 'google.protobuf.message.Message'>,)
# ]
# [autoreload of google.api_core.exceptions failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to _GoogleAPICallErrorMeta object
# ]
# [autoreload of google.protobuf.timestamp_pb2 failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/protobuf/timestamp_pb2.py", line 31, in <module>
#     _builder.BuildTopDescriptorsAndMessages(DESCRIPTOR, 'google.protobuf.timestamp_pb2', _globals)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/protobuf/internal/builder.py", line 86, in BuildTopDescriptorsAndMessages
#     module[name] = BuildMessage(msg_des)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/protobuf/internal/builder.py", line 63, in BuildMessage
#     message_class = _reflection.GeneratedProtocolMessageType(
# TypeError: A Message class can only inherit from Message, not (<class 'google.protobuf.message.Message'>,)
# ]
# [autoreload of google.auth.jwt failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/jwt.py", line 320, in <module>
#     google.auth.credentials.Signing, google.auth.credentials.CredentialsWithQuotaProject
# AttributeError: module 'google.auth' has no attribute 'credentials'
# ]
# [autoreload of google.auth._exponential_backoff failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
# ...
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/deployment_resource_pool_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]
# [autoreload of google.cloud.aiplatform_v1beta1.services.deployment_resource_pool_service.client failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/deployment_resource_pool_service/client.py", line 78, in <module>
#     from .transports.rest_asyncio import AsyncDeploymentResourcePoolServiceRestTransport
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/deployment_resource_pool_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]
# [autoreload of google.cloud.aiplatform_v1beta1.services.endpoint_service.transports failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/endpoint_service/transports/__init__.py", line 27, in <module>
#     from .rest_asyncio import AsyncEndpointServiceRestTransport
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/endpoint_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]
# [autoreload of google.cloud.aiplatform_v1beta1.services.endpoint_service.client failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/endpoint_service/client.py", line 73, in <module>
#     from .transports.rest_asyncio import AsyncEndpointServiceRestTransport
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/endpoint_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]
# [autoreload of google.cloud.aiplatform_v1beta1.services.evaluation_service.transports failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/evaluation_service/transports/__init__.py", line 27, in <module>
#     from .rest_asyncio import AsyncEvaluationServiceRestTransport
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/evaluation_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]
# [autoreload of google.cloud.aiplatform_v1beta1.services.evaluation_service.client failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/evaluation_service/client.py", line 62, in <module>
#     from .transports.rest_asyncio import AsyncEvaluationServiceRestTransport
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/evaluation_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]
# [autoreload of google.cloud.aiplatform_v1beta1.services.extension_execution_service.transports failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/extension_execution_service/transports/__init__.py", line 27, in <module>
#     from .rest_asyncio import AsyncExtensionExecutionServiceRestTransport
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/extension_execution_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]
# [autoreload of google.cloud.aiplatform_v1beta1.services.extension_execution_service.client failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/extension_execution_service/client.py", line 63, in <module>
#     from .transports.rest_asyncio import AsyncExtensionExecutionServiceRestTransport
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/extension_execution_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]
# [autoreload of google.cloud.aiplatform_v1beta1.services.extension_registry_service.transports failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/extension_registry_service/transports/__init__.py", line 27, in <module>
#     from .rest_asyncio import AsyncExtensionRegistryServiceRestTransport
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/extension_registry_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]
# [autoreload of google.cloud.aiplatform_v1beta1.services.extension_registry_service.client failed: Traceback (most recent call last):
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/extension_registry_service/client.py", line 72, in <module>
#     from .transports.rest_asyncio import AsyncExtensionRegistryServiceRestTransport
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/cloud/aiplatform_v1beta1/services/extension_registry_service/transports/rest_asyncio.py", line 21, in <module>
#     from google.auth.aio.transport.sessions import AsyncAuthorizedSession  # type: ignore
#   File "/Users/kardiff/ais/langchain-google/venv/lib/python3.9/site-packages/google/auth/aio/transport/__init__.py", line 35, in <module>
#     DEFAULT_RETRYABLE_STATUS_CODES = google.auth.transport.DEFAULT_RETRYABLE_STATUS_CODES
# AttributeError: module 'google.auth' has no attribute 'transport'
# ]

# %%
from pydantic import BaseModel, Field
from typing import Optional
from langchain_google_vertexai import ChatVertexAI, create_structured_runnable
from langchain_core.prompts import ChatPromptTemplate



_DEFAULT_MODEL_NAME = "gemini-1.0-pro-001"

class RecordPerson(BaseModel):
    """Record some identifying information about a person."""

    name: str = Field(..., description="The person's name")
    age: int = Field(..., description="The person's age")
    fav_food: Optional[str] = Field(
        default=None, description="The person's favorite food"
    )


class RecordDog(BaseModel):
    """Record some identifying information about a dog."""

    name: str = Field(..., description="The dog's name")
    color: str = Field(..., description="The dog's color")
    fav_food: Optional[str] = Field(default=None, description="The dog's favorite food")


llm = ChatVertexAI(model_name=_DEFAULT_MODEL_NAME, temperature=1.0)
prompt = ChatPromptTemplate.from_template(
    "Describe a random {class} and mention their name, {attr} and favorite food"
)
chain = create_structured_runnable(
    [RecordPerson, RecordDog], llm, prompt=prompt, use_extra_step=True
)
res = chain.invoke({"class": "person", "attr": "age"})
print(isinstance(res, RecordPerson))
# Out:
# True

# %%
from langchain_google_vertexai.model_garden_maas import (
    _LLAMA_MODELS,
    _MISTRAL_MODELS,
    get_vertex_maas_model,
)
import vertexai

vertexai.init(project="llm-integration-tests")
model_name = "mistral-nemo@2407"
llm = get_vertex_maas_model(model_name=model_name, location="us-central1")
output = llm.stream("What is the meaning of life?")
for chunk in output:
    print(chunk)
# Out:
# content='' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='The' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' meaning' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' of' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' is' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' a' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' philosophical' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' question' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' that' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' has' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' been' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' debated' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' for' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' centuries' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' it' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' doesn' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content="'t" additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' have' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' one' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' definitive' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' answer' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' as' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' it' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' can' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' vary' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' greatly' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' depending' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' on' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' personal' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' beliefs' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' religious' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' or' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' spiritual' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' views' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' individual' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' experiences' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Here' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' are' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' a' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' few' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' perspectives' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=':\n\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='1' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' **' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='Exist' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ential' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ism' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='**:' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Exist' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ential' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ists' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' like' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Jean' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='-Paul' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Sart' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='re' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Simone' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' de' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Beau' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='voir' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' argued' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' that' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' has' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' no' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' inherent' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' meaning' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' it' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content="'s" additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' up' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' to' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' each' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' individual' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' to' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' create' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' their' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' own' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' purpose' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='2' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' **' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='Rel' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='igious' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Spiritual' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Pers' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='pectives' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='**:' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Many' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' religions' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' provide' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' their' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' own' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' answers' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' For' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' example' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=':\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='  ' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' -' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' **' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='Christian' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ity' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='**:' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content="'s" additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' purpose' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' might' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' be' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' seen' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' as' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' loving' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' serving' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' God' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' preparing' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' for' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' eternal' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='  ' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' -' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' **' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='Bud' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='dh' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ism' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='**:' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' The' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' purpose' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' could' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' be' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' achieving' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' en' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='lightenment' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' escaping' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' cycle' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' of' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' reb' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='irth' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='3' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' **' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='H' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ed' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='on' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ism' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='**:' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Hed' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='on' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ists' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' believe' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' purpose' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' of' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' is' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' to' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' seek' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' pleasure' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' happiness' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='4' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' **' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='Al' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='tru' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ism' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='**:' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Some' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' people' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' find' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' meaning' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' in' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' through' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' helping' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' others' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' making' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' world' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' a' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' better' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' place' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='5' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' **' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='Personal' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Growth' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='**:' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Many' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' people' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' find' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' purpose' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' in' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' learning' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' growing' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' becoming' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' best' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' version' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' of' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' themselves' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='6' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' **' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='Bi' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ological' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Perspective' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='**:' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' From' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' a' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' scientific' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' or' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' biological' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' viewpoint' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' one' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' might' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' say' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' purpose' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' of' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' is' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' to' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' survive' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' reproduce' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='7' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' **' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='4' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='2' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='**:' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' In' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Douglas' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Adams' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content="'" additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' "' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='The' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Hitch' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='h' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='iker' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content="'s" additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Guide' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' to' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Galaxy' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',"' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' answer' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' to' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Ultimate' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Question' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' of' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Universe' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' Everything' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' is' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='...' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' ' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='4' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='2' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' It' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content="'s" additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' a' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' humorous' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' arbitrary' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' answer' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='Ultim' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='ately' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=',' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' the' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' meaning' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' of' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' may' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' be' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' a' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' deeply' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' personal' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' subjective' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' concept' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' It' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' could' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' be' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' helpful' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' to' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' reflect' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' on' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' what' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' gives' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' your' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' life' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' purpose' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' and' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' what' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' you' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' value' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content=' most' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='.' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e'
# content='' additional_kwargs={} response_metadata={} id='run-bed340e7-c9cc-429b-97d0-f1062c8cbb7e' usage_metadata={'input_tokens': 10, 'output_tokens': 335, 'total_tokens': 345}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 12
#      10 llm = get_vertex_maas_model(model_name=model_name, location="us-central1")
#      11 output = llm.stream("What is the meaning of life?")
# ---> 12 for chunk in output:
#      13     print(chunk)
#
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:420, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     413 except BaseException as e:
#     414     run_manager.on_llm_error(
#     415         e,
#     416         response=LLMResult(
#     417             generations=[[generation]] if generation else []
#     418         ),
#     419     )
# --> 420     raise e
#     421 else:
#     422     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:400, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     397     self.rate_limiter.acquire(blocking=True)
#     399 try:
# --> 400     for chunk in self._stream(messages, stop=stop, **kwargs):
#     401         if chunk.message.id is None:
#     402             chunk.message.id = f"run-{run_manager.run_id}"
#
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/langchain_mistralai/chat_models.py:590, in ChatMistralAI._stream(self, messages, stop, run_manager, **kwargs)
#     586 default_chunk_class: Type[BaseMessageChunk] = AIMessageChunk
#     587 for chunk in self.completion_with_retry(
#     588     messages=message_dicts, run_manager=run_manager, **params
#     589 ):
# --> 590     if len(chunk["choices"]) == 0:
#     591         continue
#     592     new_chunk = _convert_chunk_to_message_chunk(chunk, default_chunk_class)
#
# KeyError: 'choices'

# %%
# Using cached content in request
chat = ChatVertexAI(model_name="gemini-1.5-pro-001")
prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}"),
        ("placeholder", "{agent_scratchpad}"),
    ]
)
agent = agents.create_tool_calling_agent(
    llm=chat,
    tools=tools,
    prompt=prompt,
)
agent_executor = agents.AgentExecutor(agent=agent, tools=tools, verbose=False, stream_runnable=False)
# response = agent_executor.invoke({"input": "What is the secret number?"}, cached_content=cached_content)
response = agent_executor.invoke({"input":"What is the secret number?"}, cached_content=cached_content)
print(response)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 16
#      14 agent_executor = agents.AgentExecutor(agent=agent, tools=tools, verbose=False, stream_runnable=False)
#      15 # response = agent_executor.invoke({"input": "What is the secret number?"}, cached_content=cached_content)
# ---> 16 response = agent_executor.invoke({"What is the secret number?"}, cached_content=cached_content)
#      17 print(response)
#
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/langchain/chains/base.py:139, in Chain.invoke(self, input, config, **kwargs)
#     136 include_run_info = kwargs.get("include_run_info", False)
#     137 return_only_outputs = kwargs.get("return_only_outputs", False)
# --> 139 inputs = self.prep_inputs(input)
#     140 callback_manager = CallbackManager.configure(
#     141     callbacks,
#     142     self.callbacks,
#    (...)
#     147     self.metadata,
#     148 )
#     149 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#
# File ~/ais/langchain-google/venv/lib/python3.9/site-packages/langchain/chains/base.py:516, in Chain.prep_inputs(self, inputs)
#     512     if self.memory is not None:
#     513         # If there are multiple input keys, but some get set by memory so that
#     514         # only one is not set, we can still figure out which key it is.
#     515         _input_keys = _input_keys.difference(self.memory.memory_variables)
# --> 516     inputs = {list(_input_keys)[0]: inputs}
#     517 if self.memory is not None:
#     518     external_context = self.memory.load_memory_variables(inputs)
#
# IndexError: list index out of range
